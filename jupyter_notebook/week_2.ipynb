# %% [markdown]
# ### Week 2
# ---

# %% [markdown]
# #### Warm up

# %%
temp = int(input("Please enter the current temperature"))

if temp < 0:
    print("It's freezing! Wear a heavy jacket.")
elif temp <= 15:
    print("It's cold! Wear a sweater.")
elif temp <= 25:
    print("Nice weather! A t-shirt is fine.")
else:
    print("It's hot! Stay hydrated.")
# Out:
# It's freezing! Wear a heavy jacket.

# %% [markdown]
# #### While loop

# %%
count = 1

while count <= 5:
    print(f"Count is: {count}") # the loop continues until a certain condition is met
    count += 1 # adds 1 each time it loops over

print("Loop finished!")
# Out:
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4
# Count is: 5
# Loop finished!

# %% [markdown]
# #### Simplest possible while loop

# %%
while True:
    print("Yes")

# %% [markdown]
# #### Data types

# %% [markdown]
# * **list** – ordered, mutable sequence
# * **tuple** – ordered, immutable sequence
# * **set** – unordered collection of *unique* elements
# * **dict** – key–value pairs (dictionary, mapping type)

# %%
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_set = {1, 2, 3}
my_dict = {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# #### Conversion functions

# %%
tuple()  # Converts to a tuple
set()  # Converts to a set
list()  # Converts to a list
dict()  # Converts a tuple into a dictionary

# %% [markdown]
# #### For loops

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits: # declaring a variable called fruit and assigning it to each value in the list
    print(f"I like {fruit}!")
# Out:
# I like apple!
# I like banana!
# I like cherry!

# %%
for number in range(1, 6):  # Loops from 1 to 5
    print(f"Number: {number}")
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5

# %%
word = "Python"

for letter in word:  # Loop through each character in the string
    print(f"Letter: {letter}")

# %% [markdown]
# #### Exercise 2

# %%
for column in range(1,6):
    print("o o o o o")
# Out:
# o o o o o
# o o o o o
# o o o o o
# o o o o o
# o o o o o

# %% [markdown]
# #### Solution

# %%
n = 5
for i in range(n): # i is for each row 
    for j in range(n): # j is for each column
        print('o', end='  ')
    print()
# Out:
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o
# o  o  o  o  o

# %% [markdown]
# #### Exercise 3

# %%
n = 5
for i in range(n): # i is for each row 
    for j in range(i): # j is for each column
        print('o', end='  ')
    print()
# Out:
# o
# o  o
# o  o  o
# o  o  o  o

# %% [markdown]
# #### Break

# %%
for number in range(1, 6):  
    if number == 5:
        print("Stopping the loop!")
        break
    print(number)
    # Exits the loop when number is 5, stops the loop
# Out:
# 1
# 2
# 3
# 4
# Stopping the loop!

# %% [markdown]
# #### Pass

# %%
for number in range(1, 6):
    if number == 3:
        pass  # Placeholder; does nothing when number == 3
    else:
        print(number)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# #### Continue

# %%
for number in range(1, 6):
    if number == 3:
        continue  # goes to the next iteration
    print(number)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# #### Function

# %%
def add_numbers(a, b):
    return a + b
# function is defined and a return is assigned

result = add_numbers(3, 5)  
print(result) 
# this is now using the function and returning the a + b
# Out:
# 8

# %% [markdown]
# #### Practice

# %%
def sum_numbers():
    first = int(input("Give me a number please"))
    second = int(input("Give me another number please"))
    add = first + second
    print(f"The sum of your numbers are {add}")

sum_numbers()
# Out:
# The sum of your numbers are 10

# %% [markdown]
# #### Exercise 4

# %%
def pattern():
    rows = int(input("How many rows would you like?"))
    for i in range(rows, 0, -1): # i is for each row 
        for j in range(i): # j is for each column
            print('o', end='  ')
        print()

pattern()
# Out:
# o  o  o
# o  o
# o

# %% [markdown]
# #### Importing libraries

# %% [markdown]
# * Built-in libraries: can be used right away
# * External libraries: need to be installed first via `pip install <library name>` (run in terminal)
# * How you use your library will be defined by your import syntax!
# * **Import** section is always on top of your script

# %%
import math  # 'math' is a built-in library - an example
import math as m # lets you abbreviate within your code 
from math import sqrt  # If the library is too big, you can import just components you plan to use
from math import sqrt as s # importing a certain component and giving it an abbreviation

# %% [markdown]
# #### Matplot lib

# %% [markdown]
# Not a built in library so needs to be downloaded in the terminal as `pip install matplot lib`
# * Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
# * Seaborn is built on top of **Matplotlib**
# * In fact, in the majority of the use cases in Data Science, we use a matplotlib submodule called **`pyplot`**, which is imported under the **alias `plt`**

# %% [markdown]
# #### Example

# %%
import matplotlib.pyplot as plt  # plt is an abbreviation
import math

plt.style.use('_mpl-gallery') #setting the style of the graph

# create empty lists
x = []
y = []

# generate data using a for-loop
for i in range(0, 100):
    xi = i * 0.1        # x goes from 0 to 9.9
    yi = math.sin(xi)  # y = sin(x)

    x.append(xi)
    y.append(yi)
# append is how you add items to a list 

# plot
fig, ax = plt.subplots(figsize=(8, 4), dpi=120)

# ax.plot(x, y, 'o-', linewidth=2)
ax.scatter(x, y, marker='x')

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("y = sin(x)")

plt.show()
# visualises on screen

# %% [markdown]
# ---

# %% [markdown]
# #### Warm up

# %%
word = ["C", "h", "a", "r", "a", "c", "t", "e", "r", "i", "s", "t", "i", "c", "a", "l", "l", "y"]

search = input("Please enter a letter: ")

found = False

for letter in word:
    if letter == search:
        found = True

if found:
    print("Letter found!")
else:
    print("Letter not found!")
# Out:
# Letter found!

# %% [markdown]
# #### Variable scope
#
# * A variable created **within** the function is **local**. It is only accessible from within the function
# * A variable created **outside** the function is **global** and is 'visible' anywhere

# %%
a = "other test"
def local_global():
    a = "test string"
    return a
print(a)
# Out:
# other test

# %%
local_global()
# Out:
# 'test string'

# %% [markdown]
# #### Machine Learning Pipeline

# %% [markdown]
# * An ML pipeline is a structured way to go from raw data to a working machine learning model. It ensures that all the necessary steps are followed to train and evaluate the model.
# * Think of it as an assembly line where each step processes the data before passing it to the next stage.

# %% [markdown]
# #### Main steps
# #### 1. Data collection
# * Just like gathering ingredients for a recipe, the first step is to collect data.
# * Data can come from:
# 	* CSV files
# 	* Databases
# 	* APIs
# 	* Sensors
# * Example: Collecting customer data from a shopping website.
#
# #### 2. Data Preprocessing (Cleaning & Formatting)
# * Raw data is often messy (has missing values, duplicates, errors).
# * This step cleans the data so the model can learn properly.
# * Example Steps in Data Preprocessing:
# 	* Remove missing values or replace them
# 	* Convert text into numbers (if necessary)
# 	* Normalize data (scaling numbers to a standard range)
# * Analogy: Like washing and cutting vegetables before cooking!
#
# #### 3. Model Training
# * Here, we choose a Machine Learning algorithm and train it on the data.
# * The model learns patterns from the training data.
# * Example Algorithms:
# 	* Decision Trees
# 	* Linear Regression
# 	* Neural Networks
# * Analogy: Like a chef learning a new recipe—practicing until they get it right!
#
# #### 4. Model Evaluation
# * We test the model to see how well it performs.
# * This step ensures the model can make accurate predictions.
# * Example Metrics:
# 	* Accuracy
# 	* Precision & Recall
# 	* Mean Squared Error (MSE)
# * Analogy: Like tasting the cake to see if it's good or needs improvement!
#
# #### 5. Deployment & Predictions
# * If the model works well, we deploy it to make real-world predictions.
# * Users or applications can now use the trained model.
# * Example:
# 	* A model that predicts house prices based on location, size, and number of rooms.
# 	* A model that recommends movies based on what a user has watched before.
# * Analogy: Like serving the cake at a party!

# %% [markdown]
# #### Numpy

# %% [markdown]
# `pip install numpy`

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt  # displaying images
import PIL  # Python Imaging Library - image editing
import urllib  # Library handling URLs (like requesting)

# %% [markdown]
# * **PIL** allows opening, manipulating, and saving images in various formats (JPEG, PNG, BMP, etc.)

# %%
# Define url of an image we want to load
# This can also be a path to a local file
image_url = "https://thumbs.dreamstime.com/b/ocean-sunset-landscape-bird-high-resolution-image-flying-towards-colorful-romantic-sky-246711534.jpg"

# %%
image_data = urllib.request.urlopen(image_url)
image = PIL.Image.open(image_data)
np_image = np.array(image)

# %%
np_image.shape
# Out:
# (450, 800, 3)

# %%
plt.imshow(np_image)

# %%
image_single_color = np_image.copy()
image_single_color[:,:,2] = 0
plt.imshow(image_single_color)
